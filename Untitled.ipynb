# %%
import os
import json
import gzip
import pandas as pd
from urllib.request import urlopen
from pathlib import Path

# %%
meta_path = "D:\data\meta_All_Beauty.json.gz"
meta_path = Path(meta_path)

meta = []
with gzip.open(meta_path) as f:
    for l in f:
        meta.append(json.loads(l.strip()))

meta = pd.DataFrame(meta)

# %%
data = pd.read_csv("D:\data\All_Beauty.csv", header=None)

# %%
meta
# Out:
#       category tech1                                        description fit  \
# 0           []        [Loud 'N Clear Personal Sound Amplifier allows...
# 1           []        [No7 Lift & Luminate Triple Action Serum 50ml ...
# 2           []        [No7 Stay Perfect Foundation now stays perfect...
# 3           []                                                       []
# 4           []        [Lacto Calamine Skin Balance Daily Nourishing ...
# ...        ...   ...                                                ...  ..
# 32887       []                                                       []
# 32888       []                                                       []
# 32889       []                                                       []
# 32890       []        [Brand new and high quality<br> Enables fast v...
# 32891       []                                                       []
#
#                                                    title  \
# ...

# %%
data[data[0]=='B0000530HU']
# Out:
#                  0               1    2           3
# 6939    B0000530HU  A3SYPE5MH3BVF8  5.0  1276992000
# 6940    B0000530HU  A1KBMPE4G1JWQ4  4.0  1255824000
# 6941    B0000530HU  A2CTM1BYAXTYLX  5.0  1243987200
# 6942    B0000530HU  A3KR2C2POR3OWY  1.0  1218931200
# 6943    B0000530HU  A16FUBTF3N2O68  5.0  1218067200
# ...            ...             ...  ...         ...
# 256334  B0000530HU   AUEIKDDRA2VAV  5.0  1523232000
# 256335  B0000530HU  A1ZYCFV4JDPHUZ  4.0  1522800000
# 256336  B0000530HU  A1Y0QFDNM7IGY3  5.0  1522627200
# 256337  B0000530HU   ANBR2638OZ26C  1.0  1522454400
# 256338  B0000530HU  A2DE6RHTLKOPUY  5.0  1522281600
#
# [335 rows x 4 columns]

# %%
core_path = "D:\data\All_Beauty.json.gz"
core_path = Path(core_path)

core = []
with gzip.open(core_path) as f:
    for l in f:
        core.append(json.loads(l.strip()))

core = pd.DataFrame(core)

# %%
core
# Out:
#         overall  verified   reviewTime      reviewerID        asin  \
# 0           1.0      True  02 19, 2015  A1V6B6TNIC10QE  0143026860
# 1           4.0      True  12 18, 2014  A2F5GHSXFQ0W6J  0143026860
# 2           4.0      True  08 10, 2014  A1572GUYS7DGSR  0143026860
# 3           5.0      True  03 11, 2013   A1PSGLFK1NSVO  0143026860
# 4           5.0      True  12 25, 2011   A6IKXKZMTKGSC  0143026860
# ...         ...       ...          ...             ...         ...
# 371340      1.0      True  07 20, 2017  A202DCI7TV1022  B01HJEGTYK
# 371341      5.0      True  03 16, 2017  A3FSOR5IJOFIBE  B01HJEGTYK
# 371342      5.0      True   03 1, 2017  A1B5DK6CTP2P24  B01HJEGTYK
# 371343      2.0      True  02 21, 2017  A23OUYS5IRMJS9  B01HJEGTYK
# 371344      2.0      True  12 15, 2016  A24KQ9RVU81L87  B01HJEGTYK
#
#              reviewerName                                         reviewText  \
# 0       theodore j bigham                                              great
# ...
